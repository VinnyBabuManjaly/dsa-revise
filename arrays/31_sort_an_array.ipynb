# %% [markdown]
# Sort an Array
# Medium
# Given an array of integers nums, sort the array in ascending order and return it.
#
# You must solve the problem without using any built-in functions in O(nlog(n)) time complexity and with the smallest space complexity possible.
#
#
#
# Example 1:
#
# Input: nums = [5,2,3,1]
# Output: [1,2,3,5]
# Explanation: After sorting the array, the positions of some numbers are not changed (for example, 2 and 3), while the positions of other numbers are changed (for example, 1 and 5).
# Example 2:
#
# Input: nums = [5,1,1,2,0,0]
# Output: [0,0,1,1,2,5]
# Explanation: Note that the values of nums are not necessarily unique.
#
#
# Constraints:
#
# 1 <= nums.length <= 5 * 104
# -5 * 104 <= nums[i] <= 5 * 104

# %%
from typing import List

def sortArray(nums: List[int]) -> List[int]:
    n = len(nums) 
    if n == 1:
        return nums
    
    for i in range(n):
        for j in range(i+1, n):
            if nums[j] < nums[i]:
                nums[i], nums[j] = nums[j], nums[i]
        
    return nums

# %% [markdown]
# Exp: [5, 10, 16, 21, 22, 33]
# Inp: [21, 33, 5, 16, 10, 22]
#
# i   n[i]    j   n[j]    nums
# 0   21      1   33      21,33
#             2   5       5,33,21
#     5       3   16      5,33,21,16
#             4   10
#             5   22      5,33,21,16,10,22
#
# 1   33      2   21      5,21,33
#     21      3   16      5,16,33,21
#     16      4   10      5,10,33,21,16,
#             5   22      5,10,33,21,16,22
#
#
#
# 21, 33, 5, 16, 10, 22
#
# 21,5,16,10,22,33    6 iterations
# 5,16,10,21,22       5 iterations
# 5,10,16,21          4
# 5,10,16             3
# 5,10                2
# _____
# 33,22,21,16,10,5
#
# 22,21,16,10,5,33    5
# 21,16,10,5,22,33
#
# _____
#
# 21,33
# 21,5,33
# 21,5,16,33
# 21,5,16,10,33
# 21,5,16,10,22,33
#
#
# 5,21
# 5,16,21
# 5,16,10,21
# 5,16,10,21,22
# 5,16,10,21,22,33
#
# 5,16

# %% [markdown]
#        0   1  2   3   4   5  6
# Inp: [21, 33, 5, 16, 10, 22, 2]
#
# [12,24] [26,13]
# i   n[i]    j   n[j]
# 0   12      1   26
#
# left=0, right=len(nums)-1
# while left <= right:
#     if left==right: return
#     m = left+right//2
#     a = mergesort(left, m-1)
#     b = mergesort(m, right)
#
#
# i=j=k=0
# result = [] * len(a)+len(b)
# while(i<len(a) and j<len(b)):
#     if a[i] < a[j]:
#         result[k] = a[i]
#         i++
#     else:
#         result[k] = a[j]
#         j++
#     k++
# while(i<len(a) or j<len(b)):
#     if i<len(a): result.append(a)
#     else: result.appnd(b)

# %%
from typing import List

def sortArray(nums: List[int]) -> List[int]:
    
    def _merge_sort(left, right):
        if left >= right:
            return [nums[left]]
        
        mid = (left + right) // 2
        leftArray = _merge_sort(left, mid)
        rightArray = _merge_sort(mid+1, right)
        
        #  Merging and sorting
        l, r =len(leftArray),len(rightArray)     
        mergeArray = []
        i = j = 0
        while(i < l and j < r):
            if leftArray[i] < rightArray[j]:
                mergeArray.append(leftArray[i])
                i += 1
            else:
                mergeArray.append(rightArray[j])
                j += 1
        while i < l:
            mergeArray.append(leftArray[i])
            i += 1
        while j < r:
            mergeArray.append(rightArray[j])
            j += 1

        
        return mergeArray
    
    
    left, right = 0, len(nums)-1
    return _merge_sort(left, right)

# %% [markdown]
#        0   1  2   3   4   5  6
# Inp: [21, 33, 5, 16, 10, 22, 2]
# len(nums)=6
#
# m(0,6)  m=3
#     m(0,2)  21,33,5 m=1
#         m(0,0)  21                  21
#         m(1,2)  33,5    m=1
#             m(1,0)                  33      5
#             m(1,1)                  5
#     m(3,6)  16,10,22,2
