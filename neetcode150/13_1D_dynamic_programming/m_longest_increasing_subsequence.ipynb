# %% [markdown]
# Longest Increasing Subsequence
#
# Given an integer array nums, return the length of the longest strictly increasing subsequence.
#
# A subsequence is a sequence that can be derived from the given sequence by deleting some or no elements without changing the relative order of the remaining characters.
#
# For example, "cat" is a subsequence of "crabt".
#
# Example 1:
# Input: nums = [9,1,4,2,3,3,7]
# Output: 4
# Explanation: The longest increasing subsequence is [1,2,3,7], which has a length of 4.
#
# Example 2:
# Input: nums = [0,3,1,3,2,3]
# Output: 4
#
# Constraints:
# 1 <= nums.length <= 1000
# -1000 <= nums[i] <= 1000

# %%
class Solution:
    def lengthOfLIS(self, nums: list[int]) -> int:
        n = len(nums)
        LIS = [1] * n

        for i in range(n-1, -1, -1):
            for j in range(i+1, n):
                if nums[i] < nums[j]:
                    LIS[i] = max(LIS[i], 1+LIS[j])

        return max(LIS)

# %% [markdown]
# **Approach**: Dynamic Programming (Bottom-Up LIS)
#
# Main Logic:
# - Create an array to store the longest increasing subsequence length starting at each index.
# - Initialize all values as 1 since a single number is a valid subsequence.
# - Process the array from right to left.
# - For each number, check all numbers to its right.
# - If a larger number is found, update the subsequence length.
# - After processing all indices, return the maximum value found.
#
# Key idea:
# The longest increasing subsequence at an index depends on larger elements to its right.

# %% [markdown]
# **Time Complexity**: O(n²)
# Each pair of elements is compared once.
#
# **Space Complexity**: O(n)
# Extra array is used to store LIS values.

# %% [markdown]
# | Problem              | Longest Increasing Subsequence             |
# | -------------------- | ------------------------------------------ |
# | LeetCode Problem     | 300                                        |
# | Approach             | Dynamic Programming (Bottom-Up)            |
# | When to apply        | Subsequence optimization problems          |
# | Clues                | Increasing, subsequence, longest           |
# | Lessons learned      | Compare current choice with future options |
# | Hidden pattern       | Nested loop DP                             |
# | To recognize earlier | Subsequence with order preserved           |
# | Signal words         | Increasing, subsequence, longest           |
