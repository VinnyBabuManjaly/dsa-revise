# %% [markdown]
# House Robber II
#
# You are given an integer array nums where nums[i] represents the amount of money the ith house has. The houses are arranged in a circle, i.e. the first house and the last house are neighbors.
#
# You are planning to rob money from the houses, but you cannot rob two adjacent houses because the security system will automatically alert the police if two adjacent houses were both broken into.
#
# Return the maximum amount of money you can rob without alerting the police.
#
# Example 1:
# Input: nums = [3,4,3]
# Output: 4
# Explanation: You cannot rob nums[0] + nums[2] = 6 because nums[0] and nums[2] are adjacent houses. The maximum you can rob is nums[1] = 4.
#
# Example 2:
# Input: nums = [2,9,8,3,6]
# Output: 15
# Explanation: You cannot rob nums[0] + nums[2] + nums[4] = 16 because nums[0] and nums[4] are adjacent houses. The maximum you can rob is nums[1] + nums[4] = 15.
#
# Constraints:
# 1 <= nums.length <= 100
# 0 <= nums[i] <= 100

# %%
class Solution:
    def rob(self, nums: list[int]) -> int:
        return max(nums[0], self.helper(nums[1:]), self.helper(nums[:-1]))

    
    def helper(self, nums):
        rob1, rob2 = 0, 0

        for n in nums:
            temp = max(n+rob1, rob2)
            rob1, rob2 = rob2, temp

        return rob2

# %% [markdown]
# **Approach**: Dynamic Programming with Case Splitting (Circular House Robber)
#
# Main Logic:
# - Recognize that the first and last houses are connected in a circle.
# - You cannot rob both the first and the last house together.
# - Split the problem into two linear cases.
#     - First case: skip the first house and rob from the remaining houses.
#     - Second case: skip the last house and rob from the remaining houses.
# - Use the standard House Robber logic for each case.
# - Return the maximum result from all valid cases.
#
# Key idea:
# - Convert a circular constraint into multiple linear problems and take the best result.

# %% [markdown]
# **Time Complexity**: O(n)
# Each house is processed a constant number of times.
#
# **Space Complexity**: O(1)
# Only a few variables are used for computation.

# %% [markdown]
# | Problem              | House Robber II                                   |
# | -------------------- | ------------------------------------------------- |
# | LeetCode Problem     | 213                                               |
# | Approach             | Dynamic Programming + Case Split                  |
# | When to apply        | Circular arrangement with adjacency constraints   |
# | Clues                | Circular houses, first and last adjacent          |
# | Lessons learned      | Break circular problems into linear cases         |
# | Hidden pattern       | Linear DP reused with constraints                 |
# | To recognize earlier | First and last elements cannot be chosen together |
# | Signal words         | Circular, rob, adjacent houses                    |
