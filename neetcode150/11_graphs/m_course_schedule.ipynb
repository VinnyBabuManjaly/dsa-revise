# %% [markdown]
# [Course Schedule](https://leetcode.com/problems/course-schedule/description/)
#
# Medium
# There are a total of numCourses courses you have to take, labeled from 0 to numCourses - 1. You are given an array prerequisites where prerequisites[i] = [ai, bi] indicates that you must take course bi first if you want to take course ai.
#
# For example, the pair [0, 1], indicates that to take course 0 you have to first take course 1.
# Return true if you can finish all courses. Otherwise, return false.
#
# Example 1:
# Input: numCourses = 2, prerequisites = [[1,0]]
# Output: true
# Explanation: There are a total of 2 courses to take.
# To take course 1 you should have finished course 0. So it is possible.
#
# Example 2:
# Input: numCourses = 2, prerequisites = [[1,0],[0,1]]
# Output: false
# Explanation: There are a total of 2 courses to take.
# To take course 1 you should have finished course 0, and to take course 0 you should also have finished course 1. So it is impossible.
#
# Constraints:
# 1 <= numCourses <= 2000
# 0 <= prerequisites.length <= 5000
# prerequisites[i].length == 2
# 0 <= ai, bi < numCourses
# All the pairs prerequisites[i] are unique.

# %%
from collections import defaultdict

def canFinish(numCourses: int, prerequisites: list[list[int]]) -> bool:
    status = [0] * numCourses
    graph = defaultdict(list)

    for coursea, courseb in prerequisites:
        graph[courseb].append(coursea)

    def dfs(course):
        if status[course] == 2:
            return True

        if status[course] == 1:
            return False

        status[course] = 1
        for pre in graph[course]:
            if not dfs(pre):
                return False
        status[course] = 2
        return True

    for course in range(numCourses):
        if not dfs(course):
            return False

    return True

# %%
from collections import defaultdict

class Solution:
    def canFinish(self, numCourses: int, prerequisites: List[List[int]]) -> bool:
        preMap = defaultdict(list)
        visit = set()

        for course, prereq in prerequisites:
            preMap[course].append(prereq)

        def dfs(course):
            if course in visit:
                return False
            if not preMap[course]:
                return True


            visit.add(course)
            for prereq in preMap[course]:
                if not dfs(prereq):
                    return False
            
            preMap[course] = []
            visit.remove(course)
            return True

        for i in range(numCourses):
            if not dfs(i):
                return False

        return True

# %% [markdown]
# **Approach: DFS Cycle Detection (Graph Traversal)**
#
#  **Main Logic**
#
# * Build a graph from prerequisites (who depends on whom).
# * Keep track of each course’s state:
#   **unvisited**, **currently exploring**, **fully processed**.
# * Start DFS from each course.
# * If DFS reaches a course that is **already being explored**, a cycle exists → return `False`.
# * If all courses finish exploring without detecting a cycle → return `True`.
#
#  **Key Idea**
#
# A cycle in the prerequisite graph means courses are **mutually dependent**, so it’s impossible to finish all courses.
# Detect cycles using DFS by tracking the current recursion path.

# %% [markdown]
# **Complexity**
#
# **Time Complexity**: **O(V + E)**
# Each course (V) and prerequisite (E) is processed once.
#
# **Space Complexity**: **O(V + E)**
# Graph storage + recursion stack + state tracking.

# %% [markdown]
# | Problem              | Course Schedule                                         |
# | -------------------- | ------------------------------------------------------- |
# | LeetCode Problem     | 207                                                     |
# | Approach             | DFS Cycle Detection                                     |
# | When to apply        | When checking feasibility of tasks with dependencies    |
# | Clues                | Courses, prerequisites, ordering, possible / impossible |
# | Lessons learned      | Cycles in dependency graphs prevent completion          |
# | Hidden pattern       | Directed graph cycle detection                          |
# | To recognize earlier | Problems about tasks, scheduling, dependencies          |
# | Signal words         | Prerequisite, before, depends on, can you finish        |
