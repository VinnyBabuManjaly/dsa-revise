# %% [markdown]
# # Set Matrix Zeroes
#
# Given an m x n matrix of integers matrix, if an element is 0, set its entire row and column to 0's.
#
# You must update the matrix in-place.
#
# Follow up: Could you solve it using O(1) space?
#
# Example 1:
# Input: matrix = [
#   [0,1],
#   [1,0]
# ]
# Output: [
#   [0,0],
#   [0,0]
# ]
#
# Example 2:
# Input: matrix = [
#   [1,2,3],
#   [4,0,5],
#   [6,7,8]
# ]
# Output: [
#   [1,0,3],
#   [0,0,0],
#   [6,0,8]
# ]
#
# Constraints:
# 1 <= matrix.length, matrix[0].length <= 100
# -2^31 <= matrix[i][j] <= (2^31) - 1

# %%
from typing import List

class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        rows, cols = len(matrix), len(matrix[0])
        rowZero = 1

        for r in range(rows):
            for c in range(cols):
                if matrix[r][c] == 0:
                    matrix[0][c] = 0

                    if r > 0:
                        matrix[r][0] = 0
                    else:
                        rowZero = 0

        for r in range(1, rows):
            for c in range(1, cols):
                if matrix[r][0] == 0 or matrix[0][c] == 0:
                    matrix[r][c] = 0

        if matrix[0][0] == 0:
            for r in range(rows):
                matrix[r][0] = 0

        if rowZero == 0:
            for c in range(cols):
                matrix[0][c] = 0

# %% [markdown]
# ### Approach: In-place Marking using First Row and Column
#
# **Main Logic:**
#
# * Use first row and first column as markers to track which rows and columns should be zeroed.
# * Traverse the matrix:
#
#   * If a cell is 0, mark its row and column using first row/column.
#   * Use a separate variable to track if the first row itself should be zero.
# * Traverse the matrix again (excluding first row/column):
#
#   * Set cell to 0 if its row or column is marked.
# * Finally:
#
#   * Update first column if needed.
#   * Update first row if needed.
#
# **Key idea:**
# Reuse the matrix itself as storage to avoid extra space.

# %% [markdown]
# **Time Complexity**: O(m × n)
# Each cell is visited twice.
#
# **Space Complexity**: O(1)
# No extra space used apart from variables.

# %% [markdown]
# | Problem              | Set Matrix Zeroes                                        |
# | -- | -- |
# | LeetCode Problem     | 73                                                       |
# | Approach             | In-place Marking using First Row/Column                  |
# | When to apply        | Modify matrix based on row/column conditions             |
# | Clues                | “Set entire row and column to zero”, “in-place”          |
# | Lessons learned      | Use matrix itself to store state instead of extra arrays |
# | Hidden pattern       | Marker-based transformation                              |
# | To recognize earlier | Need O(1) space optimization                             |
# | Signal words         | set zeroes, in-place, matrix                             |

# %% [markdown]
# ### What can be learned from this problem?
#
# * First row/column can act as efficient markers.
# * Space optimization often comes from reusing input structure.
# * Careful handling of edge cases (first row/column) is critical.
