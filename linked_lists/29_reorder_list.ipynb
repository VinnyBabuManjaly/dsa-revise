# %% [markdown]
# Reorder List
# You are given the head of a singly linked-list. The list can be represented as:
# L0 → L1 → … → Ln - 1 → Ln
# Reorder the list to be on the following form:
# L0 → Ln → L1 → Ln - 1 → L2 → Ln - 2 → …
# You may not modify the values in the list's nodes. Only nodes themselves may be changed.
#
# Example 1:
# Input: head = [1,2,3,4]
# Output: [1,4,2,3]
# Example 2:
# Input: head = [1,2,3,4,5]
# Output: [1,5,2,4,3]
#
# Constraints:
# The number of nodes in the list is in the range [1, 5 * 104].
# 1 <= Node.val <= 1000

# %%
from typing import Optional

class ListNode():
    def __init__(self, val, next=None):
        self.val = val
        self.next = next
        
def reorderList(head:ListNode) -> Optional[ListNode]:
    if not head or not head.next:
        return
    
    # finding the middle
    slow, fast = head, head
    while fast and fast.next:
        slow, fast = slow.next, fast.next.next
        
    # breaking linked list from slow.next in the middle
    # Reversing the second half
    prev = None
    curr = slow.next
    slow.next = None
    
    while curr:
        next = curr.next
        curr.next = prev
        prev = curr
        curr = next
        
    # prev is the head of the reversed second half
    first, second = head, prev
    
    while second:
        tmp1 = first.next
        tmp2 = second.next
        
        first.next = second
        second.next = tmp1
        
        first = tmp1
        second = tmp2

# %% [markdown]
# 1->2->3->4->5->6
# 1->6->2->5->3->4
# slow, fast = head, head
#     while fast and fast.next:
#         slow, fast = slow.next, fast.next.next
#
# 1->2->3->4->5->6->None
# slow    fast
# 1       1
# 2       3
# 3       5
# 4       None

# %% [markdown]
# #breaking linked list from slow.next in the middle
#     # Reversing the second half
#     prev = None
#     curr = slow.next
#     slow.next = None
#
#     while curr:
#         next = curr.next
#         curr.next = prev
#         prev = curr
#         curr = next
#
# prev=None, curr=5, 4.next=None
# 1->2->3->4->None
# 5->6
#
# next    curr.next   prev    curr
# 6       5->None     5       6
# None    6->5        6       None
#
# 6->5->None

# %% [markdown]
#  # prev is the head of the reversed second half
#     first, second = head, prev
#
#     while second:
#         tmp1 = first.next
#         tmp2 = second.next
#
#         first.next = second
#         second.next = tmp1
#
#         first = tmp1
#         second = tmp2
#
# 1->2->3->4->None
# 6->5->None
#
# first   second  tmp1    tmp2    f.nxt   s.next
# 1       6
# 1       6       2       5       6       2       1->6->2
# 2       5       3       None    5       3       2->5->3
# 3       None
#
# 1 6 2 5 3 4 None
